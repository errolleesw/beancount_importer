# %% [markdown]
# # Beancount transaction processor
# This Jupyter notebook processes my monthly transactions.
#
# ## Download statements
#
# ## Setup virtual environment
# ### Create venv
# ```bash
# python3 -m venv beancount-venv
# source beancount-venv/bin/activate
# ```

# %% [markdown]
# ## Step 1 Install Python Pre-requisites

# %%
# !source jupyter-venv/bin/activate
# !pip install --upgrade pip
# !pip install -r /home/errol/beancount/importer/requirements.txt
# Out:
# Requirement already satisfied: pip in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (25.1.1)
# Requirement already satisfied: jupyter in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: beancount in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: pandas in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: numpy in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 4)) (2.2.4)
# Requirement already satisfied: requests in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 6)) (4.13.3)
# Requirement already satisfied: lxml in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 7)) (5.3.1)
# Requirement already satisfied: pdfplumber in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 8)) (0.11.6)
# Requirement already satisfied: pytz in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: python-dotenv in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: openai in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 11)) (1.70.0)
# Requirement already satisfied: pathlib in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: fuzzywuzzy in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 13)) (0.18.0)
# Requirement already satisfied: scikit-learn in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 14)) (1.6.1)
# Requirement already satisfied: fava in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from -r /home/errol/beancount/importer/requirements.txt (line 15)) (1.30.2)
# Requirement already satisfied: notebook in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (7.3.3)
# Requirement already satisfied: jupyter-console in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (6.6.3)
# Requirement already satisfied: nbconvert in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (7.16.6)
# Requirement already satisfied: ipykernel in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: ipywidgets in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (8.1.5)
# Requirement already satisfied: jupyterlab in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (4.3.6)
# Requirement already satisfied: click>=7.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beancount->-r /home/errol/beancount/importer/requirements.txt (line 2)) (8.1.8)
# Requirement already satisfied: python-dateutil>=2.6.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beancount->-r /home/errol/beancount/importer/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: regex>=2022.9.13 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beancount->-r /home/errol/beancount/importer/requirements.txt (line 2)) (2024.11.6)
# Requirement already satisfied: tzdata>=2022.7 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pandas->-r /home/errol/beancount/importer/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from requests->-r /home/errol/beancount/importer/requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from requests->-r /home/errol/beancount/importer/requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from requests->-r /home/errol/beancount/importer/requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from requests->-r /home/errol/beancount/importer/requirements.txt (line 5)) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beautifulsoup4->-r /home/errol/beancount/importer/requirements.txt (line 6)) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beautifulsoup4->-r /home/errol/beancount/importer/requirements.txt (line 6)) (4.13.1)
# Requirement already satisfied: pdfminer.six==20250327 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pdfplumber->-r /home/errol/beancount/importer/requirements.txt (line 8)) (20250327)
# Requirement already satisfied: Pillow>=9.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pdfplumber->-r /home/errol/beancount/importer/requirements.txt (line 8)) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pdfplumber->-r /home/errol/beancount/importer/requirements.txt (line 8)) (4.30.1)
# Requirement already satisfied: cryptography>=36.0.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pdfminer.six==20250327->pdfplumber->-r /home/errol/beancount/importer/requirements.txt (line 8)) (44.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (2.11.2)
# Requirement already satisfied: sniffio in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: httpcore==1.* in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai->-r /home/errol/beancount/importer/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from scikit-learn->-r /home/errol/beancount/importer/requirements.txt (line 14)) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from scikit-learn->-r /home/errol/beancount/importer/requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from scikit-learn->-r /home/errol/beancount/importer/requirements.txt (line 14)) (3.6.0)
# Requirement already satisfied: Babel<3,>=2.11 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (2.17.0)
# Requirement already satisfied: Flask-Babel<5,>=3 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (4.0.0)
# Requirement already satisfied: Flask<4,>=2.2 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=3 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: Werkzeug<4,>=2.2 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: beanquery<0.3,>=0.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: beangulp>=0.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (0.2.0)
# Requirement already satisfied: cheroot<11,>=8 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (10.0.1)
# Requirement already satisfied: markdown2<3,>=2.3.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (2.5.3)
# Requirement already satisfied: ply in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (3.11)
# Requirement already satisfied: simplejson<4,>=3.16.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (3.20.1)
# Requirement already satisfied: watchfiles>=0.20.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (1.0.4)
# Requirement already satisfied: tatsu-lts in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beanquery<0.3,>=0.1->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (5.13.1)
# Requirement already satisfied: more-itertools>=2.6 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from cheroot<11,>=8->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (10.6.0)
# Requirement already satisfied: jaraco.functools in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from cheroot<11,>=8->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (4.1.0)
# Requirement already satisfied: itsdangerous>=2.2 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from Flask<4,>=2.2->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from Flask<4,>=2.2->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from Jinja2<4,>=3->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (3.0.2)
# Requirement already satisfied: chardet in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beangulp>=0.1->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (5.2.0)
# Requirement already satisfied: python-magic>=0.4.12 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from beangulp>=0.1->fava->-r /home/errol/beancount/importer/requirements.txt (line 15)) (0.4.27)
# Requirement already satisfied: cffi>=1.12 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber->-r /home/errol/beancount/importer/requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: pycparser in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber->-r /home/errol/beancount/importer/requirements.txt (line 8)) (2.22)
# Requirement already satisfied: six>=1.5 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from python-dateutil>=2.6.0->beancount->-r /home/errol/beancount/importer/requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (9.0.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (24.2)
# Requirement already satisfied: psutil in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (5.14.3)
# Requirement already satisfied: decorator in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: stack_data in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from ipywidgets->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (3.0.13)
# Requirement already satisfied: async-lru>=1.0.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (78.1.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: json5>=0.9.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.24.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.1.1)
# Requirement already satisfied: fqdn in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: isoduration in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: uri-template in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (24.11.1)
# Requirement already satisfied: bleach!=5.0.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (6.2.0)
# Requirement already satisfied: defusedxml in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: webencodings in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.21.1)
# Requirement already satisfied: arrow>=0.15.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.9.0.20241206)
# Requirement already satisfied: executing>=1.2.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/errol/beancount/beancount-venv/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter->-r /home/errol/beancount/importer/requirements.txt (line 1)) (0.2.3)

# %% [markdown]
# ## Import transactions from source files
# - Input = source files
# - Output = json file with transactions

# %%
import pdfplumber
import requests
import json
from typing import List
from datetime import datetime

# %% [markdown]
# ### Define source file extraction funtions

# %%
def extract_text_from_pdf(pdf_path: str) -> List[str]:
    """Extract text from PDF, returning a list of text content per page"""
    page_contents = []
    
    with pdfplumber.open(pdf_path) as pdf:
        print(f"Processing PDF with {len(pdf.pages)} pages...")
        for page_num, page in enumerate(pdf.pages, 1):
            print(f"Extracting text from page {page_num}...")
            text = page.extract_text()
            if text.strip():  # Only add non-empty pages
                page_contents.append(text)
    
    return page_contents

def process_page(text: str, url: str, headers: dict) -> List[dict]:
    """Process a single page of text through Ollama with strict JSON validation"""
    prompt = f"""
    Extract all transactions from this Westpac bank statement page.
    Respond ONLY with a JSON array. Each object in the array must have these exact properties:
    [
        {{"Date": "YYYY-MM-DD", "Description": "string", "Amount": number}}
    ]
    
    --- Start of Page ---
    {text}
    --- End of Page ---
    """
    
    payload = {
        "model": model,
        "system": """You are a JSON-only API endpoint. 
        1. ONLY output valid JSON arrays
        2. Each object MUST have exactly: Date (YYYY-MM-DD), Description (string), Amount (number)
        3. NO explanation text
        4. NO markdown formatting
        5. NO natural language
        If you can't extract valid transactions, return an empty array []""",
        "prompt": prompt,
        "temperature": 0,
        "max_tokens": 2000,
        "stream": True  # Enable streaming for better response handling
    }
    
    try:
        full_response = ""
        response = requests.post(url, headers=headers, json=payload, stream=True)
        
        if response.status_code == 200:
            # Process the streamed response
            for line in response.iter_lines():
                if line:
                    chunk = json.loads(line)
                    full_response += chunk.get("response", "")
            
            # Clean up the response to ensure valid JSON
            cleaned_response = full_response.strip()
            # Remove any non-JSON text before the first [
            cleaned_response = cleaned_response[cleaned_response.find("["):]
            # Remove any text after the last ]
            cleaned_response = cleaned_response[:cleaned_response.rfind("]")+1]
            
            try:
                # Validate JSON structure
                parsed_data = json.loads(cleaned_response)
                if not isinstance(parsed_data, list):
                    print("Warning: Response is not a JSON array")
                    return []
                    
                # Validate each transaction object
                valid_transactions = []
                for trans in parsed_data:
                    if all(key in trans for key in ["Date", "Description", "Amount"]):
                        valid_transactions.append(trans)
                    else:
                        print(f"Warning: Skipping invalid transaction: {trans}")
                
                return valid_transactions
                
            except json.JSONDecodeError as e:
                print(f"Warning: Invalid JSON response: {e}")
                print(f"Raw response: {cleaned_response[:100]}...")
                return []
                
    except Exception as e:
        print(f"Error processing page: {e}")
        return []
    

def import_csv_amazon(file_path):
    """Import Amazon Orders purchased with Gift Cards from csv file of Amazon Order history from "Amazon Order History Reporter" Chrome Extension into a standardized DataFrame."""
    if "Amazon" not in os.path.basename(file_path):
        print(f"Skipping file {file_path}: does not contain 'Amazon' in the file name.")
        return None
    try:
        # Load the CSV into a DataFrame
        df = pd.read_csv(file_path)
        # Rename specific columns
        df = df.rename(columns={
            "order id": "OrderID",
            "order url": "OrderURL",
            "items": "Description",
            "to": "To",
            "date": "Date",
            "total": "Total",
            "shipping": "Shipping",
            "shipping_refund": "ShippingRefund",
            "gift": "Gift",
            "refund": "Refund",
            "payments": "Payments",
            "Invoice": "Invoice"
        })
        # Format the Date column to a datetime type
        df['Date'] = pd.to_datetime(df['Date'], format="%Y-%m-%d", errors="coerce")

        # Convert numeric columns to numeric data types
        numeric_columns = ["Total", "Shipping", "ShippingRefund", "Gift", "Refund"]
        for col in numeric_columns:
            df[col] = pd.to_numeric(df[col], errors="coerce").fillna(0)  # Coerce errors to NaN and fill them with 0
    
        df['Amount'] = -df['Gift'] # Amount is the Gift amount only. We only want orders that were paid with Gift Cards
        df['TotalAmount'] = -(df['Total'] + df['Shipping'] - df['ShippingRefund'] + df['Gift']) # Total amount of the order

        # Select columsn into standardized DataFrame
        standardized_df = df[['Date', 'Description', 'Amount', 'TotalAmount', 'OrderURL', 'Refund']]
        standardized_df = standardized_df[standardized_df['Amount'] < 0] # Only select orders that were paid with Gift Cards
        
        # print(standardized_df.columns)
        # print(standardized_df)

        return standardized_df

    except FileNotFoundError:
        print(f"Error: The file {file_path} was not found.")
    except pd.errors.EmptyDataError:
        print("Error: The file is empty.")
    except KeyError as e:
        print(f"Error: Missing expected column in CSV: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")
        return None  # Return None to indicate failure

def import_json_woolworths(file_path, start_date=None, end_date=None):
    """
    Extracts transaction details, receipt totals, and amounts paid by gift cards from Woolworths JSON data.
    Optionally filters transactions based on a start and end date.

    Args:
        file_path (str): Path to the JSON file.
        start_date (str): Start date in "YYYY-MM-DD" format (optional).
        end_date (str): End date in "YYYY-MM-DD" format (optional).

    Returns:
        pd.DataFrame: A DataFrame containing transaction details including receipt totals and gift card payments.
    """
    try:
        with open(file_path, "r") as file:
            data = json.load(file)

        transactions = []
        perth_tz = pytz.timezone("Australia/Perth")  # Define Perth timezone

        for entry in data.get("download", []):
            # Extract transaction-level details with safe default values
            transaction_id = entry.get("id", None)
            display_date = entry.get("displayDate", None)
            title = entry.get("title", None)
            description = entry.get("description", None)
            transaction = entry.get("transaction", {})
            transaction_type = entry.get("transactionType", None)
            amount = transaction.get("amountAsDollars", "").replace("$", "") if transaction else None
            origin = transaction.get("origin", None) if transaction else None
            capture_time = entry.get("captureTime", None)

            # Parse captureTime to use as the reference datetime
            reference_datetime = None
            if capture_time:
                try:
                    reference_datetime = datetime.fromisoformat(capture_time.replace("Z", "+00:00")).astimezone(perth_tz)
                except Exception as e:
                    print(f"Error parsing captureTime for entry {transaction_id}: {e}")

            # Determine the transaction date using Display Date and Title
            transaction_date = None
            if display_date and reference_datetime:
                try:
                    # Parse day and month from display_date
                    day_month = datetime.strptime(display_date, "%a %d %b")  # Parse day and month
                    year = reference_datetime.year  # Default to the current year

                    if title == "Last Month":
                        # Handle transactions from the previous month
                        last_month = reference_datetime.month - 1 or 12
                        year -= 1 if last_month == 12 else 0
                        transaction_date = day_month.replace(year=year, month=last_month)
                    elif title == "This Month":
                        # Handle transactions from the current month
                        transaction_date = day_month.replace(year=year, month=reference_datetime.month)
                    else:
                        # Handle specific months and years in the title (e.g., "August 2023")
                        try:
                            # Extract the month and year from the title
                            month_year_match = re.match(r"(\w+)\s+(\d{4})", title)
                            if month_year_match:
                                month = datetime.strptime(month_year_match.group(1), "%B").month
                                year = int(month_year_match.group(2))
                                transaction_date = day_month.replace(year=year, month=month)
                            else:
                                # Handle specific months without a year in the title
                                month = datetime.strptime(title, "%B").month
                                transaction_date = day_month.replace(year=year, month=month)
                        except ValueError:
                            pass  # Ignore invalid formats
                except Exception as e:
                    print(f"Error parsing transaction date for entry {transaction_id}: {e}")

            # Extract eReceipt details safely
            ereceipt = entry.get("ereceipt", {}).get("activityDetails", {}).get("tabs", [])
            gift_card_payment = 0
            receipt_total = 0

            if ereceipt:
                receipt_details = ereceipt[0].get("page", {}).get("details", [])

                # Extract Receipt Total
                for detail in receipt_details:
                    if detail.get("__typename") == "ReceiptDetailsTotal":
                        receipt_total = float(detail.get("total", "0").replace("$", ""))
                        break

                # Extract Gift Card Payments
                payments = ereceipt[0].get("page", {}).get("details", [])
                for payment in payments:
                    if payment.get("__typename") == "ReceiptDetailsPayments":
                        for method in payment.get("payments", []):
                            payment_description = method.get("description", "") or ""
                            alt_text = method.get("altText", "") or ""

                            # Check if "Gift" exists in either description or altText
                            if "Gift" in payment_description or "Gift" in alt_text:
                                gift_card_payment += float(method.get("amount", "0").replace("$", ""))

            transactions.append({
                "TransactionID": transaction_id,
                "TransactionType": transaction_type,
                "Title": title,
                "Date": transaction_date.strftime("%Y-%m-%d") if transaction_date else None,
                "DisplayDate": display_date,
                "Description": description,
                "Origin": origin,
                "TotalAmount": receipt_total,
                "Amount": gift_card_payment,
            })

        # Convert the list of transactions to a DataFrame
        df = pd.DataFrame(transactions)

        # Format the Date column to a datetime type
        df['Date'] = pd.to_datetime(df['Date'], format="%Y-%m-%d", errors="coerce")

        # Standardize the DataFrame
        standardized_df = df[['Date', 'Description', 'Amount', 'TotalAmount', 'Origin']]
        # Filter rows and create a new copy of the DataFrame
        standardized_df = standardized_df[standardized_df['Amount'] > 0]

        # Modify the 'Amount' column safely
        standardized_df['Amount'] = -standardized_df['Amount']  # Convert Gift Card payments to negative amounts

        # Apply the date filter on the standardized DataFrame
        if start_date:
            start_date = datetime.strptime(start_date, "%Y-%m-%d").date()
            standardized_df = standardized_df[standardized_df['Date'] >= start_date.isoformat()]
        if end_date:
            end_date = datetime.strptime(end_date, "%Y-%m-%d").date()
            standardized_df = standardized_df[standardized_df['Date'] <= end_date.isoformat()]

        return standardized_df

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %% [markdown]
# ### Extract transactions into JSON

# %%
import os
import pathlib
import glob
import pandas as pd
import json
from datetime import datetime
import pytz
import re

# Configurations
url = "http://192.168.5.44:11434/api/generate"
model = "llama3.1"
headers = {"Content-Type": "application/json"}
input_dir = "/home/errol/beancount/importer/00_inputs"
output_dir = "/home/errol/beancount/importer/01_outputs"
os.makedirs(output_dir, exist_ok=True)
start_date = "2025-03-22"
end_date = "2025-05-31"

def standardize_transactions(transactions: list) -> list:
    """Standardize transaction format for both PDF and CSV sources"""
    standardized = []
    for trans in transactions:
        # Create standardized transaction dictionary
        std_trans = {
            "Date": trans.get("Date"),
            "Description": trans.get("Description"),
            "Amount": float(trans.get("Amount", 0)),
            "Source": trans.get("Source", "Unknown"),
            "URL": trans.get("OrderURL", ""),
            "Refund": trans.get("Refund", 0),
            "Category": trans.get("Category", "")  # Added for Woolworths categories
        }
        standardized.append(std_trans)
    return standardized

def process_file(file_path: str) -> None:
    """Process a single file (PDF, CSV, or JSON) and store results in a DataFrame and JSON"""
    print(f"\nProcessing file: {os.path.basename(file_path)}")
    print("-" * 50)
    
    # Create matching JSON filename
    file_name = pathlib.Path(file_path).stem
    json_output_path = os.path.join(output_dir, f"{file_name}.json")
    
    # Process based on file type
    file_ext = pathlib.Path(file_path).suffix.lower()
    all_transactions = []
    
    if file_ext == '.pdf':
        pages = extract_text_from_pdf(file_path)
        print(f"Extracted {len(pages)} pages with content")
        
        for i, page_text in enumerate(pages, 1):
            print(f"Processing page {i}/{len(pages)}...")
            page_results = process_page(page_text, url, headers)
            if page_results:
                for transaction in page_results:
                    try:
                        date_str = transaction['Date']
                    # Handle both 'dd mmm yyyy' and 'dd-mmm-yyyy' formats
                        if '-' in date_str:
                            date_obj = datetime.strptime(date_str, '%d-%b-%Y')
                        else:
                            date_obj = datetime.strptime(date_str, '%d %b %Y')
                        transaction['Date'] = date_obj.strftime('%Y-%m-%d')
                        transaction['Source'] = 'Westpac'
                    except ValueError as e:
                        print(f"Warning: Invalid date format in transaction: {transaction['Date']}")
                    continue
            all_transactions.extend(page_results)
                
    elif file_ext == '.csv':
        df = import_csv_amazon(file_path)
        if df is not None:
            csv_transactions = df.to_dict('records')
            for trans in csv_transactions:
                trans['Date'] = trans['Date'].strftime('%Y-%m-%d')
                trans['Source'] = 'Amazon'
            all_transactions.extend(csv_transactions)
            
    elif file_ext == '.json':
        print(f"Processing Woolworths JSON file: {file_path}")
        df = import_json_woolworths(file_path, start_date, end_date)
        
        if df is not None and not df.empty:
            json_transactions = df.to_dict('records')
            for trans in json_transactions:
                trans['Source'] = 'Woolworths'
                if isinstance(trans['Date'], pd.Timestamp):
                    trans['Date'] = trans['Date'].strftime('%Y-%m-%d')
            all_transactions.extend(json_transactions)
            print(f"Processed {len(json_transactions)} Woolworths transactions")
        else:
            print(f"No valid transactions found in {file_path}")
    
    if all_transactions:
        # Standardize and sort transactions
        all_transactions = standardize_transactions(all_transactions)
        all_transactions.sort(key=lambda x: x['Date'])
        
        # # Convert to DataFrame
        # df_transactions = pd.DataFrame(all_transactions)
        # globals()[file_name] = df_transactions
        # print(f"Created DataFrame '{file_name}' with {len(df_transactions)} transactions")
        
        # Save to JSON file
        with open(json_output_path, 'w') as f:
            json.dump(all_transactions, f, indent=2)
        print(f"Saved transactions to: {json_output_path}")

def main():
    # Find all PDF, CSV, and JSON files in input directory
    input_files = glob.glob(os.path.join(input_dir, "*.pdf"))
    input_files.extend(glob.glob(os.path.join(input_dir, "*.csv")))
    input_files.extend(glob.glob(os.path.join(input_dir, "*.json")))
    
    if not input_files:
        print(f"No PDF, CSV, or JSON files found in: {input_dir}")
        return
    
    print(f"Found {len(input_files)} files to process")
    
    # Process each file
    for file_path in sorted(input_files):
        try:
            process_file(file_path)
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
    
    # Print summary
    print("\nProcessing Complete")
    print("-" * 50)
    print(f"Input directory: {input_dir}")
    print(f"Output directory: {output_dir}")
    print(f"Total files processed: {len(input_files)}")

if __name__ == "__main__":
    main()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Found 8 files to process
#
# Processing file: 2025-05-24 Amazon-order-history.csv
# --------------------------------------------------
# Saved transactions to: /home/errol/beancount/importer/01_outputs/2025-05-24 Amazon-order-history.json
#
# Processing file: 2025-05-24 Deloitte-Amex transactions.csv
# --------------------------------------------------
# Skipping file /home/errol/beancount/importer/00_inputs/2025-05-24 Deloitte-Amex transactions.csv: does not contain 'Amazon' in the file name.
#
# Processing file: 2025-05-24 ING Blow-32970834 Transacteions.pdf
# --------------------------------------------------
# Processing PDF with 2 pages...
# Extracting text from page 1...
# Extracting text from page 2...
# Extracted 2 pages with content
# Processing page 1/2...
# Processing page 2/2...
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Warning: Invalid date format in transaction: 2025-04-23
# Warning: Invalid date format in transaction: 2025-04-24
# Warning: Invalid date format in transaction: 2025-04-24
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-05-01
# Warning: Invalid date format in transaction: 2025-05-05
# Warning: Invalid date format in transaction: 2025-05-05
# Warning: Invalid date format in transaction: 2025-05-05
# Warning: Invalid date format in transaction: 2025-05-07
# Warning: Invalid date format in transaction: 2025-05-11
# Warning: Invalid date format in transaction: 2025-05-12
# Warning: Invalid date format in transaction: 2025-05-15
# Warning: Invalid date format in transaction: 2025-05-15
# Warning: Invalid date format in transaction: 2025-05-16
# Warning: Invalid date format in transaction: 2025-05-16
# Warning: Invalid date format in transaction: 2025-05-18
# Warning: Invalid date format in transaction: 2025-05-18
# Warning: Invalid date format in transaction: 2025-05-19
# Warning: Invalid date format in transaction: 2025-05-20
# Saved transactions to: /home/errol/beancount/importer/01_outputs/2025-05-24 ING Blow-32970834 Transacteions.json
#
# Processing file: 2025-05-24 Westpac Altitude-Credit-479923 Statement.pdf
# --------------------------------------------------
# Processing PDF with 7 pages...
# Extracting text from page 1...
# Extracting text from page 2...
# Extracting text from page 3...
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Extracting text from page 4...
# Extracting text from page 5...
# Extracting text from page 6...
# Extracting text from page 7...
# Extracted 7 pages with content
# Processing page 1/7...
# Warning: Invalid date format in transaction: 2025-05-22
# Warning: Invalid date format in transaction: 2025-05-22
# Warning: Invalid date format in transaction: 2025-05-21
# Warning: Invalid date format in transaction: 2025-05-21
# Warning: Invalid date format in transaction: 2025-05-21
# Warning: Invalid date format in transaction: 2025-05-21
# Warning: Invalid date format in transaction: 2025-05-20
# Warning: Invalid date format in transaction: 2025-05-20
# Warning: Invalid date format in transaction: 2025-05-20
# Warning: Invalid date format in transaction: 2025-05-20
# Warning: Invalid date format in transaction: 2025-05-18
# Warning: Invalid date format in transaction: 2025-05-18
# Warning: Invalid date format in transaction: 2025-05-18
# Warning: Invalid date format in transaction: 2025-05-18
# Warning: Invalid date format in transaction: 2025-05-16
# Warning: Invalid date format in transaction: 2025-05-16
# Processing page 2/7...
# Warning: Invalid date format in transaction: 2024-05-16
# Warning: Invalid date format in transaction: 2024-05-16
# Warning: Invalid date format in transaction: 2024-05-16
# Warning: Invalid date format in transaction: 2024-05-16
# Warning: Invalid date format in transaction: 2024-05-16
# Warning: Invalid date format in transaction: 2024-05-15
# Warning: Invalid date format in transaction: 2024-05-14
# Warning: Invalid date format in transaction: 2024-05-13
# Warning: Invalid date format in transaction: 2024-05-13
# Warning: Invalid date format in transaction: 2024-05-13
# Warning: Invalid date format in transaction: 2024-05-12
# Warning: Invalid date format in transaction: 2024-05-11
# Warning: Invalid date format in transaction: 2024-05-10
# Warning: Invalid date format in transaction: 2024-05-09
# Warning: Invalid date format in transaction: 2024-05-09
# Warning: Invalid date format in transaction: 2024-05-09
# Warning: Invalid date format in transaction: 2024-05-09
# Warning: Invalid date format in transaction: 2024-05-09
# Warning: Invalid date format in transaction: 2024-05-09
# Warning: Invalid date format in transaction: 2024-05-08
# Warning: Invalid date format in transaction: 2024-05-08
# Warning: Invalid date format in transaction: 2024-05-08
# Warning: Invalid date format in transaction: 2024-05-08
# Warning: Invalid date format in transaction: 2024-05-08
# Warning: Invalid date format in transaction: 2024-05-07
# Processing page 3/7...
# Processing page 4/7...
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-26
# Warning: Invalid date format in transaction: 2025-04-25
# Warning: Invalid date format in transaction: 2025-04-23
# Warning: Invalid date format in transaction: 2025-04-22
# Warning: Invalid date format in transaction: 2025-04-22
# Warning: Invalid date format in transaction: 2025-04-21
# Warning: Invalid date format in transaction: 2025-04-21
# Warning: Invalid date format in transaction: 2025-04-20
# Warning: Invalid date format in transaction: 2025-04-20
# Warning: Invalid date format in transaction: 2025-04-20
# Warning: Invalid date format in transaction: 2025-04-20
# Warning: Invalid date format in transaction: 2025-04-20
# Warning: Invalid date format in transaction: 2025-04-20
# Warning: Invalid date format in transaction: 2025-04-18
# Warning: Invalid date format in transaction: 2025-04-18
# Warning: Invalid date format in transaction: 2025-04-18
# Warning: Invalid date format in transaction: 2025-04-17
# Warning: Invalid date format in transaction: 2025-04-17
# Processing page 5/7...
# Processing page 6/7...
# Processing page 7/7...
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Warning: Invalid date format in transaction: 2025-03-22
# Saved transactions to: /home/errol/beancount/importer/01_outputs/2025-05-24 Westpac Altitude-Credit-479923 Statement.json
#
# Processing file: 2025-05-24 Westpac Blow-524631 Statement.pdf
# --------------------------------------------------
# Processing PDF with 1 pages...
# Extracting text from page 1...
# Extracted 1 pages with content
# Processing page 1/1...
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Saved transactions to: /home/errol/beancount/importer/01_outputs/2025-05-24 Westpac Blow-524631 Statement.json
#
# Processing file: 2025-05-24 Westpac Joint-785669 Statement.pdf
# --------------------------------------------------
# Processing PDF with 1 pages...
# Extracting text from page 1...
# Extracted 1 pages with content
# Processing page 1/1...
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Saved transactions to: /home/errol/beancount/importer/01_outputs/2025-05-24 Westpac Joint-785669 Statement.json
#
# Processing file: 2025-05-24 Westpac Loan-343233 Statement.pdf
# --------------------------------------------------
# Processing PDF with 1 pages...
# Extracting text from page 1...
# Extracted 1 pages with content
# Processing page 1/1...
# Saved transactions to: /home/errol/beancount/importer/01_outputs/2025-05-24 Westpac Loan-343233 Statement.json
#
# Processing file: 2025-05-24 Woolworths-receipt.json
# --------------------------------------------------
# Processing Woolworths JSON file: /home/errol/beancount/importer/00_inputs/2025-05-24 Woolworths-receipt.json
# An error occurred: 'str' object has no attribute 'get'
# No valid transactions found in /home/errol/beancount/importer/00_inputs/2025-05-24 Woolworths-receipt.json
#
# Processing Complete
# --------------------------------------------------
# Input directory: /home/errol/beancount/importer/00_inputs
# Output directory: /home/errol/beancount/importer/01_outputs
# Total files processed: 8

# %% [markdown]
# ## Process Transactions

# %%
from beancount.core import data, amount
from beancount.core.number import Decimal
from beancount.parser.printer import format_entry
from beancount.loader import load_file
from beancount.core import account_types

from datetime import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

def get_expense_accounts(bean_file: str) -> set:
    """Extract expense accounts from a Beancount file"""
    entries, errors, _ = load_file(bean_file)
    
    # Get all account open directives
    expense_accounts = set()
    for entry in entries:
        if isinstance(entry, data.Open) and entry.account.startswith('Expenses:'):
            expense_accounts.add(entry.account)
    
    return expense_accounts

def find_matching_transactions(beanfile_path, new_transaction_desc, threshold=0.5):
    """
    Finds transactions in the Beancount file where the 'src_desc' metadata field
    matches the description of a new transaction using TF-IDF and cosine similarity.

    Args:
        beanfile_path (str): Path to the Beancount file.
        new_transaction_desc (str): Description of the new transaction.
        threshold (float): Minimum cosine similarity score to consider a match (0-1).

    Returns:
        list: A list of tuples containing matching transactions and their similarity scores.
    """
    entries, errors, _ = load_file(beanfile_path)
    if errors:
        raise ValueError(f"Errors occurred while loading the Beancount file: {errors}")

    # Collect all transaction descriptions
    descriptions = []
    valid_entries = []
    
    for entry in entries:
        if isinstance(entry, data.Transaction):
            metadata = entry.meta or {}
            src_desc = str(metadata.get('src-desc', ''))
            if src_desc:
                descriptions.append(src_desc.lower())
                valid_entries.append(entry)

    if not descriptions:
        return []

    # Create TF-IDF vectors
    vectorizer = TfidfVectorizer(lowercase=True, analyzer='char_wb', ngram_range=(2,3))
    tfidf_matrix = vectorizer.fit_transform(descriptions + [new_transaction_desc.lower()])
    
    # Calculate cosine similarity
    similarity_scores = cosine_similarity(
        tfidf_matrix[-1:], 
        tfidf_matrix[:-1]
    )[0]

    # Find matches above threshold
    matching_transactions = [
        (valid_entries[i], float(score))
        for i, score in enumerate(similarity_scores)
        if score >= threshold
    ]
    
    # Sort by similarity score in descending order
    matching_transactions.sort(key=lambda x: x[1], reverse=True)
    
    print(f"\nFound {len(matching_transactions)} matching transactions for '{new_transaction_desc}'")
    return matching_transactions

def classify_expense(description: str, url: str, headers: dict, expense_accounts: set, matching_transactions: list) -> str:
    """
    Use Ollama to classify transaction description into a Beancount expense category
    """
    # Convert accounts set to formatted string for prompt
    account_list = '\n'.join(f'- {account}' for account in sorted(expense_accounts))
    
    matching_transactions_list = '\n'.join(f"\nMatch ratio: {score}%\n{format_entry(entry)}"
    for entry, score in matching_transactions)
    
    prompt = f"""
    Classify this transaction into a Beancount expense account category.
    Transaction: "{description}"
    
    Similar transactions from Beancount with similarity scores:
    {matching_transactions_list}
    
    Using the simmilar transactions as reference, use ONLY these categories (return ONLY the category name, no other text):
    {account_list}
    
    If unable to classify, return "Expenses:FIXME"
    """
    
    payload = {
        "model": model,
        "system": "You are a transaction classifier. Respond ONLY with the exact category name, no other text.",
        "prompt": prompt,
        "temperature": 0,
        "max_tokens": 100,
        "stream": True
    }
    
    try:
        full_response = ""
        response = requests.post(url, headers=headers, json=payload, stream=True)
        
        if response.status_code == 200:
            for line in response.iter_lines():
                if line:
                    chunk = json.loads(line)
                    full_response += chunk.get("response", "")
            
            # Clean up response and validate category
            category = full_response.strip()
            
            # Debug output
            print(f"Raw response: '{full_response}'")
            print(f"Cleaned category: '{category}'")
            print(f"Is in expense_accounts: {category in expense_accounts}")
            print(f"Available accounts: {expense_accounts}")
            
            return category if category in expense_accounts else 'Expenses:FIXME'
    except Exception as e:
        print(f"Error classifying transaction: {e}")
        return 'Expenses:FIXME'
    
import json
from beancount.core import data, amount
from beancount.core.number import Decimal
from beancount.parser.printer import format_entry
from datetime import datetime
# from fuzzywuzzy import fuzz
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def create_beancount_entries(
    json_file: str,
    bean_accounts_file: str,
    bean_transactions_file: str,
    url: str,
    headers: dict,
    output_file: str,
    account_mapping: dict
) -> None:
    """
    Create Beancount transactions from a JSON file and classify them using Ollama.
    Writes the output to a .bean file.

    Args:
        json_file (str): Path to the input JSON file.
        bean_accounts_file (str): Path to the Beancount file with expense account definitions.
        bean_transactions_file (str): Path to the Beancount file with existing transactions.
        url (str): URL of the Ollama model server.
        headers (dict): Headers for the Ollama HTTP request.
        output_file (str): Path to the output .bean file.
        assets_account (str): Default assets account for these transactions.
    """
    json_filename = os.path.basename(json_file)

    assets_account = next(
        (account for key, account in account_mapping.items() 
         if key.lower() in json_filename.lower()),
        'Assets:Cash'  # Default if no match found
    )

    entries = []
    expense_accounts = get_expense_accounts(bean_accounts_file)

    with open(json_file, 'r') as f:
        transactions = json.load(f)

    for txn in transactions:
        txn_date = datetime.strptime(txn['Date'], '%Y-%m-%d').date()
        description = txn['Description'].strip()
        txn_url = txn['URL']
        amt = Decimal(str(txn['Amount']))
        refund = Decimal(str(txn['Refund']))

        meta = data.new_metadata(json_file, 0)
        meta['src_desc'] = txn.get('Description', 'Unknown')
        meta['url'] = txn_url

        if amt < 0:
            matching_transactions = find_matching_transactions(bean_transactions_file, description)
            expense_account = classify_expense(description, url, headers, expense_accounts, matching_transactions)
            postings = [
                data.Posting(account=expense_account, units=amount.Amount(-amt, 'AUD'), cost=None, price=None, flag=None, meta=None),
                data.Posting(account=assets_account, units=amount.Amount(amt, 'AUD'), cost=None, price=None, flag=None, meta=None)
            ]
        elif refund > 0:
            matching_transactions = find_matching_transactions(bean_file, description)
            expense_account = classify_expense(description, url, headers, expense_accounts,matching_transactions)
            postings = [
                data.Posting(account=assets_account, units=amount.Amount(refund, 'AUD'), cost=None, price=None, flag=None, meta=None),
                data.Posting(account=expense_account, units=amount.Amount(-refund, 'AUD'), cost=None, price=None, flag=None, meta=None)
            ]
        else:
            continue

        txn_entry = data.Transaction(
            meta=meta,
            date=txn_date,
            flag='*',
            payee=txn.get('Source', 'Amazon'),
            narration=description,
            tags=set(),
            links=set(),
            postings=postings
        )

        entries.append(txn_entry)

    # beancount_text = '\n\n'.join(format_entry(entry) for entry in entries)
    beancount_text = '\n\n'.join(format_entry(entry) for entry in entries)
    # print(beancount_text)

    with open(output_file, 'w') as f:
        f.write(beancount_text)

    print(f"Beancount entries written to {output_file}")

# %%
# beanfile_path = "/home/errol/beancount/ledger_prod/main.bean"
# search_term = "woolworths"

# results = find_matching_transactions(beanfile_path, search_term)

# print(results)

# for transaction, ratio in results:
#   print(f"\nMatch ratio: {ratio}%")
#   print(format_entry(transaction))

# %%
ACCOUNT_MAPPING = {
  'Amazon-order-history': 'Assets:00-Personal:10-Non-Current-Assets:Gift-Cards:Amazon',
  'ING Blow-32970834': 'Assets:00-Personal:00-Current-Assets:ING:Blow-32970834',
  'Westpac Altitude-Credit-479923': 'Liabilities:01-Joint:Westpac:Altitude-Credit-479923',
  'Westpac Blow-524631': 'Assets:00-Personal:00-Current-Assets:Westpac:Blow-524631',
  'Westpac Joint-785669': 'Assets:01-Joint:00-Current-Assets:Westpac:Joint-785669',
  'Westpac Loan-343233': 'Liabilities:01-Joint:Westpac:Pyrus-Loan',
  'Woolworths-receipt': 'Assets:00-Personal:10-Non-Current-Assets:Gift-Cards:Woolworths'
}

# %%
# bean_file = "/home/errol/beancount/ledger_prod/main.bean"
# json_file = "/home/errol/beancount/importer/01_outputs/2025-03-21 Westpac Altitude-Credit-479923 Statement.json"


# output = create_beancount_entries(
#     json_file,
#     bean_file,
#     url=url,
#     headers=headers,
#     output_file="/home/errol/beancount/importer/01_outputs/test.bean",
#     account_mapping=ACCOUNT_MAPPING
# )

# print(output)

# %%
import os
import glob

# Define your paths
input_dir = '/home/errol/beancount/importer/01_outputs'  # Directory containing JSON files
output_dir = '/home/errol/beancount/importer/02_beancount'
bean_accounts_file= '/home/errol/beancount/ledger_prod/accounts.bean'  # Update to your Beancount file with expense account definitions
bean_transactions_file = '/home/errol/beancount/ledger_prod/main.bean'  # Update to your Beancount file with existing transactions

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# List all JSON files in the input directory
json_files = glob.glob(os.path.join(input_dir, '*.json'))

# Process each JSON file and output a corresponding .bean file
for json_file in json_files:
    base_name = os.path.basename(json_file)
    file_name_without_ext, _ = os.path.splitext(base_name)
    output_file = os.path.join(output_dir, f"{file_name_without_ext}.bean")
    
    create_beancount_entries(
        json_file=json_file,
        bean_accounts_file=bean_accounts_file,
        bean_transactions_file=bean_transactions_file,
        url=url,
        headers=headers,
        output_file=output_file,
        account_mapping=ACCOUNT_MAPPING
    )
    print(f"Processed {json_file} -> {output_file}")
# Out:
# Found 2 matching transactions for 'ThermoPro TP350 Humidity Meter with Large Backlit LCD Display, Bluetooth Thermometer with Humidity Sensor, Hygrometer;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Lodge 3 Quart Enameled Cast Iron Dutch Oven with Lid – Dual Handles – Oven Safe up to 500° F or on Stovetop - Use to Marinate, Cook, Bake, Refrigerate and Serve – Indigo;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'PALMER'S Coconut Oil Formula Body Lotion, 400ml;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 3 matching transactions for 'OMO Ultimate Front & Top Loader Laundry Liquid 2 L;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Wash Wild Floor Wash 1L, Natural Lemon Eucalyptus Scent, Concentrated & Non-toxic formula, Safe on all surfaces;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Wash Wild Dishwashing Liquid 1 Litre;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Crayola 12 Washable Sidewalk Chalks, Outdoor toys for kids, bright colours, Non-toxic, Creative play outside;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'HOWARD PRODUCTS Australia Feed-N-Wax FW0016 Premium Beeswax & Orange Oil Wood Polish and Conditioner, 473ml | Effective at Preventing Wood Deterioration and Dryness and Maintaining Wood Finishes;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'UGREEN SATA III to USB 3.0 Adapter Cable with UASP Converter for 2.5" 3.5” Hard Drives Disk HDD and Solid State SSD;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Carefree Original Unscented Liners 48 pack;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 3 matching transactions for 'OMO Ultimate Sensitive Front & Top Loader Laundry Liquid 2 L;'
# Raw response: 'Expenses:01-Joint:00-Essentials:Food:Groceries'
# Cleaned category: 'Expenses:01-Joint:00-Essentials:Food:Groceries'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Cocobella Coconut Water Straight Up, 6 x 1L;'
# Raw response: 'Expenses:00-Personal:00-Essentials:Food:Cafes'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:Food:Cafes'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'HUGGIES Baby Wipes Fragrance Free 640 Pack (8 x 80 Pack) - Packaging May Vary;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Quilton 3 Ply Aloe Vera Facial tissues, (12 boxes of 110 tissues);'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Glad Wrap, 300 Metre Clear Cling Wrap, BPA-Free, Microwave Ready, 300m x 33cm, 1 Count;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Amazon Basics 36 Pack AAA High-Performance Alkaline Batteries, 10-Year Shelf Life, Easy to Open Value Pack;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Flower Crown Pattern Art Design - Customizable Cat Dog ID Tags Suitable for Small Pets - Stainless Steel Deep Engraving Gold Charm;'
# Raw response: 'Expenses:00-Personal:01-Splurge:Accessories'
# Cleaned category: 'Expenses:00-Personal:01-Splurge:Accessories'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'SKYN Selection Non-Latex Condoms - Contains SKYN Elite, Original, Excitation, Extra Lube, Condoms, 36 Count;'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 1 matching transactions for 'Huggies Ultra Dry Nappies Girls Size 5 (13-18kg) 128 Count - One Month Supply (Packaging May Vary);'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 0 matching transactions for 'Ethernet Cable 10m, Cat 6e/Cat6 Ethernet Cable High Speed with Network Patch Cords, LAN Cable with Rj45 Connector for Router Modem Faster Than Cat 5e/Cat 5-White; 0.3m 0.5m 1m 2m 3m 5m 10m 15m 20m 30m 50m 100m RJ45 CAT6 Ethernet Network LAN Patch Cable 1000Mbps (20m);'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 0 matching transactions for 'Cable Matters 3-Pack 6Gbps SATA Cable - 45cm, SATA Cables for SSD, SATA3.0, Black;'
# Raw response: 'Expenses:00-Personal:01-Splurge:Tech'
# Cleaned category: 'Expenses:00-Personal:01-Splurge:Tech'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 0 matching transactions for 'Ma petite bibliothèque - T'choupi et les animaux;'
# Raw response: 'Expenses:00-Personal:00-Essentials:Food:Cafes'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:Food:Cafes'
# Is in expense_accounts: True
# ...
# Raw response: 'Expenses:00-Personal:00-Essentials:Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:Misc'
# Is in expense_accounts: False
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 0 matching transactions for 'Beem\3cae98cc5cbf40b09a7 withdrawal -$79.25 $2,369.86'
# Raw response: 'Expenses:00-Personal:01-Splurge:Food:Dining-Out'
# Cleaned category: 'Expenses:00-Personal:01-Splurge:Food:Dining-Out'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 2 matching transactions for 'Edmund Lee Costco -$83.64 $2,286.22'
# Raw response: 'Expenses:01-Joint:00-Essentials:Food:Groceries'
# Cleaned category: 'Expenses:01-Joint:00-Essentials:Food:Groceries'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 2 matching transactions for 'Edmund Lee Costco -$50.97 $2,235.25'
# Raw response: 'Expenses:01-Joint:00-Essentials:Food:Groceries'
# Cleaned category: 'Expenses:01-Joint:00-Essentials:Food:Groceries'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 0 matching transactions for 'ALLIANZ AUST -$204.63 $2,030.62'
# Raw response: 'Expenses:01-Joint:00-Essentials:Food:Cafes'
# Cleaned category: 'Expenses:01-Joint:00-Essentials:Food:Cafes'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
# Beancount entries written to /home/errol/beancount/importer/02_beancount/2025-05-24 ING Blow-32970834 Transacteions.bean
# Processed /home/errol/beancount/importer/01_outputs/2025-05-24 ING Blow-32970834 Transacteions.json -> /home/errol/beancount/importer/02_beancount/2025-05-24 ING Blow-32970834 Transacteions.bean
#
# Found 0 matching transactions for 'INTEREST -$2746.73'
# Raw response: 'Expenses:00-Personal:01-Splurge:00-Misc'
# Cleaned category: 'Expenses:00-Personal:01-Splurge:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
#
# Found 0 matching transactions for 'INTEREST -$2664.74'
# Raw response: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Cleaned category: 'Expenses:00-Personal:00-Essentials:00-Misc'
# Is in expense_accounts: True
# Available accounts: {'Expenses:01-Joint:00-Essentials:Home:Pool', 'Expenses:01-Joint:02-Smile:Vacation:Accomodation', 'Expenses:01-Joint:00-Essentials:Utilities:Electricity', 'Expenses:Govt-Fees:Transfer-Fees', 'Expenses:01-Joint:00-Essentials:Insurance:Pet', 'Expenses:01-Joint:00-Essentials:Car:00-Misc', 'Expenses:00-Personal:01-Splurge:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Home-Contents', 'Expenses:01-Joint:02-Smile:Vacation:00-Misc', 'Expenses:01-Joint:00-Essentials:Gifts', 'Expenses:01-Joint:00-Essentials:Sport', 'Expenses:01-Joint:00-Essentials:Utilities:Internet', 'Expenses:00-Personal:01-Splurge:Accessories', 'Expenses:01-Joint:01-Splurge:00-Misc', 'Expenses:00-Personal:01-Splurge:Entertainment', 'Expenses:00-Personal:00-Essentials:Food:Takeaway', 'Expenses:Depreciation', 'Expenses:00-Personal:01-Splurge:Food:Dining-Out', 'Expenses:01-Joint:00-Essentials:Tech:00-Misc', 'Expenses:01-Joint:00-Essentials:Home:Maintainence', 'Expenses:01-Joint:00-Essentials:Pets', 'Expenses:10-Merrol-Trust:Tax', 'Expenses:01-Joint:00-Essentials:Food:Groceries', 'Expenses:00-Personal:01-Splurge:Clothing', 'Expenses:01-Joint:00-Essentials:Food:Cafes', 'Expenses:01-Joint:00-Essentials:Food:Takeaway', 'Expenses:01-Joint:00-Essentials:00-Misc', 'Expenses:01-Joint:00-Essentials:Car:Maintenance', 'Expenses:01-Joint:00-Essentials:Utilities:Water', 'Expenses:00-Personal:02-Smile:00-Misc', 'Expenses:01-Joint:00-Essentials:Insurance:Medical', 'Expenses:01-Joint:00-Essentials:Car:Fuel', 'Expenses:01-Joint:01-Splurge:Children', 'Expenses:00-Personal:00-Essentials:00-Misc', 'Expenses:00-Personal:00-Essentials:Food:Cafes', 'Expenses:00-Personal:01-Splurge:Gifts', 'Expenses:10-Merrol-Trust:Trading:Fees', 'Expenses:00-Personal:01-Splurge:Tech', 'Expenses:01-Joint:00-Essentials:Home:Interest-Pyaments', 'Expenses:00-Personal:01-Splurge:Hobbies:Swim-Bike-Run', 'Expenses:01-Joint:00-Essentials:Tech:Subscriptions', 'Expenses:01-Joint:00-Essentials:Utilities:Gas'}
# Beancount entries written to /home/errol/beancount/importer/02_beancount/2025-05-24 Westpac Loan-343233 Statement.bean
# Processed /home/errol/beancount/importer/01_outputs/2025-05-24 Westpac Loan-343233 Statement.json -> /home/errol/beancount/importer/02_beancount/2025-05-24 Westpac Loan-343233 Statement.bean

# %%
# # get_expense_accounts('/home/errol/beancount/ledger_prod/accounts.bean')
# # load_file('/home/errol/beancount/ledger_prod/main.bean')
# find_matching_transactions(
#     '/home/errol/beancount/ledger_prod/main.bean',
#     'Woolworths 1234567890',
#     threshold=0.5
# )

# x = classify_expense(
#     'Woolworths 1234567890',
#     url=url,
#     headers=headers,
#     expense_accounts=get_expense_accounts('/home/errol/beancount/ledger_prod/accounts.bean'),
#     matching_transactions=find_matching_transactions(
#         '/home/errol/beancount/ledger_prod/main.bean',
#         'Woolworths 1234567890',
#         threshold=0.5
#     )
# )

# print(f"Classified expense: {x}")
